# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from sklearn.feature_selection import RFE
import os
import seaborn as sns
import matplotlib.pyplot as plt


# Plotting the confusion matrix
def plot_confusion_matrix(cm, class_names):
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.title('Confusion Matrix')
    plt.show()


def plot_classification_report(classification_report, cmap='coolwarm'):
    """
    Plots a heatmap of a classification report.
    
    Parameters:
    classification_report (dict): The classification report as a dictionary, typically output from sklearn.metrics.classification_report.
    cmap (str): The colormap for the heatmap. Default is 'coolwarm'.
    """
    # Convert the classification report to a DataFrame
    report_df = pd.DataFrame(classification_report).transpose()
    
    # Set the plot size
    plt.figure(figsize=(10, 5))
    
    # Plot the heatmap
    sns.heatmap(report_df, annot=True, cmap=cmap, fmt='.2f', linewidths=.5, cbar_kws={'label': 'Score'})
    
    # Set the labels and title
    plt.xlabel('Metrics')
    plt.ylabel('Classes')
    plt.title('Classification Report')
    
    # Display the plot
    plt.show()

# %% [markdown]
# ## Select only data from sign up form

# %%
# Load your dataframe
dataset_name = r"BastianLewisData_final.csv"
data_dir = r"C:\Users\peter\Projects\HR_Forecasting\data"
df = pd.read_csv(os.path.join(data_dir,dataset_name))

# Remove stage, status, groupid
cols = [col for col in df.columns.to_list() if col not in ['stage','status','groupid']]
cols = [col for col in cols if "GroupTitle" not in col]
cols = [col for col in cols if "StageTitle" not in col]

df = df[cols]

# %%
df.columns.to_list()
# Out:
# ['cdate',
#  'recruitercode',
#  'belafspraak',
#  'leeftijd',
#  'geboortedatum',
#  'Verloning marge stopper of W&S overname',
#  'Overname bedrag (W&S)',
#  'starter',
#  'berekening',
#  'jaar_ervaring',
#  'randstad',
#  'diff_days',
#  'randstad.1',
#  'utm_source_bing',
#  'utm_source_facebook',
#  'utm_source_fb-ig',
#  'utm_source_google',
#  'utm_source_indeed',
#  'utm_source_nationaleberoepengids',
#  'utm_source_other',
#  'utm_source_strevon',
#  'utm_source_tiktok',
#  'utm_source_undefined',
#  'utm_medium_cpc',
#  'utm_medium_organic',
#  'utm_medium_social',
#  'utm_medium_undefined',
#  'utm_campaign_algemeen_amsterdam',
#  'utm_campaign_algemeen_rotterdam',
#  'utm_campaign_awareness',
#  'utm_campaign_branding',
#  'utm_campaign_chat-popup',
#  'utm_campaign_consideration',
#  'utm_campaign_consideration_elektromonteur',
#  'utm_campaign_elektromonteur',
#  'utm_campaign_elektromonteur_amsterdam',
#  'utm_campaign_elektromonteur_rotterdam',
#  'utm_campaign_elektromonteur_utrecht',
#  'utm_campaign_elektrotechniek',
#  'utm_campaign_installatiemonteur',
#  'utm_campaign_installatiemonteur-exp',
#  'utm_campaign_installatiemonteur_amsterdam',
#  'utm_campaign_installatiemonteur_denhaag',
#  'utm_campaign_installatiemonteur_exp',
#  'utm_campaign_installatiemonteur_gouda',
#  'utm_campaign_installatiemonteur_rotterdam',
#  'utm_campaign_installatiemonteur_utrecht',
#  'utm_campaign_installatietechniek',
#  'utm_campaign_other',
#  'utm_campaign_retargeting',
#  'utm_campaign_undefined',
#  'utm_campaign_zonnepanelen_monteur_rotterdam',
#  'utm_campaign_zonnepanelen_monteur_utrecht',
#  'utm_adgroup_DSA_LP_Optin',
#  'utm_adgroup_DSA_LP_Optin_Elektro',
#  'utm_adgroup_DSA_LP_Optin_Installatie',
#  'utm_adgroup_bbl_opleiding_algemeen',
#  'utm_adgroup_betaalde_opleiding',
#  'utm_adgroup_betaalde_opleiding_EXP',
#  'utm_adgroup_elektricien_opleiding',
#  'utm_adgroup_elektromonteur_bbl',
#  'utm_adgroup_elektromonteur_opleiding',
#  'utm_adgroup_elektrotechniek_bbl_amsterdam',
#  'utm_adgroup_elektrotechniek_bbl_utrecht',
#  'utm_adgroup_elektrotechniek_cursus',
#  'utm_adgroup_elektrotechniek_opleiding',
#  'utm_adgroup_elektrotechniek_opleiding_amsterdam',
#  'utm_adgroup_elektrotechniek_opleiding_utrecht',
#  'utm_adgroup_installateur_opleiding',
#  'utm_adgroup_installateur_opleiding_amsterdam',
#  'utm_adgroup_installateur_opleiding_rotterdam',
#  'utm_adgroup_installateur_opleiding_utrecht',
#  'utm_adgroup_installatietechniek_bbl',
#  'utm_adgroup_installatietechniek_opleiding',
#  'utm_adgroup_loodgieter_bbl',
#  'utm_adgroup_loodgieter_bbl_amsterdam',
#  'utm_adgroup_loodgieter_bbl_utrecht',
#  'utm_adgroup_loodgieter_omscholing_amsterdam',
#  'utm_adgroup_loodgieter_opleiding',
#  'utm_adgroup_loodgieter_opleiding_amsterdam',
#  'utm_adgroup_loodgieter_opleiding_rotterdam',
#  'utm_adgroup_loodgieter_opleiding_utrecht',
#  'utm_adgroup_loodgieter_worden',
#  'utm_adgroup_loodgieter_worden_amsterdam',
#  'utm_adgroup_loodgieter_worden_utrecht',
#  'utm_adgroup_omscholingstraject',
#  'utm_adgroup_opleiding_elektricien',
#  'utm_adgroup_other',
#  'utm_adgroup_undefined',
#  'utm_adgroup_vacature_elektrotechniek',
#  'utm_adgroup_vacature_installatiemonteur',
#  'utm_adgroup_werk_leer_traject',
#  'utm_adgroup_werkleertraject',
#  'utm_adgroup_werkleertraject_EXP',
#  'utm_adgroup_zonnepanelen_opleiding_utrecht',
#  'referrer_8kvl4ikw535.typeform.com',
#  'referrer_direct',
#  'referrer_instagram.com',
#  'referrer_l.facebook.com',
#  'referrer_lm.facebook.com',
#  'referrer_m.facebook.com',
#  'referrer_nl.indeed.com',
#  'referrer_other',
#  'referrer_strevon.nl',
#  'referrer_undefined',
#  'referrer_www.adsensecustomsearchads.com',
#  'referrer_www.bing.com',
#  'referrer_www.google.com',
#  'referrer_www.google.nl',
#  'referrer_www.nationaleberoepengids.nl',
#  'referrer_www.tiktok.com',
#  'conversiepunt_leadform',
#  'conversiepunt_other',
#  'conversiepunt_website',
#  'pagina_',
#  'pagina_contact',
#  'pagina_omscholing-elektrotechniek-optin',
#  'pagina_omscholing-elektrotechniek-sea-4',
#  'pagina_omscholing-installatiemonteur-optin',
#  'pagina_omscholing-installatiemonteur-sea-4',
#  'pagina_omscholing-zonnepanelenmonteur-optin',
#  'pagina_omscholing-zonnepanelenmonteur-sea-4',
#  'pagina_omscholing-zonwering-optin',
#  'pagina_opleidingstrajecten-bouw-techniek',
#  'pagina_opleidingstrajecten-techniek-paid',
#  'pagina_opleidingstrajecten/elektrotechniek',
#  'pagina_opleidingstrajecten/elektrotechniek/avondopleiding',
#  'pagina_opleidingstrajecten/elektrotechniek/bbl',
#  'pagina_opleidingstrajecten/elektrotechniek/elektricien',
#  'pagina_opleidingstrajecten/installatietechniek',
#  'pagina_opleidingstrajecten/installatietechniek/airco-monteur',
#  'pagina_opleidingstrajecten/installatietechniek/cv-monteur',
#  'pagina_opleidingstrajecten/installatietechniek/installateur',
#  'pagina_opleidingstrajecten/installatietechniek/loodgieter',
#  'pagina_opleidingstrajecten/zonnepanelen-installateur',
#  'pagina_opleidingstrajecten/zonnepanelen-monteur',
#  'pagina_other',
#  'pagina_over-ons',
#  'pagina_vacatures-bouw-techniek/zonder-diploma',
#  'pagina_vacatures/installatietechniek',
#  'pagina_vacatures/zonnepanelen/zonnepanelen-installateur/zzp',
#  'pagina_vacatures/zonnepanelen/zonnepanelen-installateur/zzp/salaris',
#  'uitkomstTelefonischContact_Intake',
#  'Ben je in het bezit van rijbewijs?_ja',
#  'Ben je in het bezit van rijbewijs?_other',
#  'beschikking tot eigen vervoer?_ja een eigen auto of motor',
#  'beschikking tot eigen vervoer?_ja een eigen scooter',
#  'beschikking tot eigen vervoer?_nee dit heb ik niet',
#  'score 1_Gordijnen ophangen, batterij vervangen rookmelder, lampje verwisselen',
#  'score 1_Laminaat leggen, lampen aansluiten op elektra, sleutelen aan scooter/auto',
#  'score 1_Meer dan een half jaar ervaring in een technische functie (bijvoorbeeld monteur)',
#  'score 2_Gordijnen ophangen, batterij vervangen rookmelder, lampje verwisselen',
#  'score 2_Houtwerk schilderen, leidingen verleggen, vervangen van kapotte stopcontacten',
#  'score 2_Laminaat leggen, lampen aansluiten op elektra, sleutelen aan scooter/auto',
#  'score 2_Meer dan een half jaar ervaring in een technische functie (bijvoorbeeld monteur)',
#  'score 2_Stofzuigerzak vervangen, verwijderen oude poster, dakgoot schoonmaken',
#  'score 3_Kast in elkaar zetten, monteren nieuwe douchekop, deurbel installeren',
#  'score 3_Meer dan een half jaar ervaring in een technische functie (bijvoorbeeld monteur)',
#  'score 3_Vervangen batterij afstandsbediening, schoonmaken afzuigkap, vastdraaien losse schroef',
#  'Voorkeursbranche_elektrotechniek',
#  'Voorkeursbranche_geen voorkeur',
#  'Voorkeursbranche_installatietechniek',
#  'Voorkeursbranche_zonnepanelen',
#  'Voorkeursbranche_zonwering',
#  'Motivatie_Ik ben hier nog niet over uit',
#  'Motivatie_Ik sta alleen open voor de technische branche en/of iets gerelateerd hieraan',
#  'Motivatie_Ik sta ook open voor een andere branche (bijvoorbeeld: horeca, retail, logistiek, etc.).',
#  'Motivatie_other',
#  'Werksituatie_ik ben werkloos',
#  "Werksituatie_ik ben zzp'er",
#  'Werksituatie_ik heb een tijdelijk contract (bepaalde tijd)',
#  'Werksituatie_ik heb een vast contract',
#  'Huidig/Laatste functie_2',
#  'Huidig/Laatste functie_3',
#  'Huidig/Laatste functie_4',
#  'Huidig/Laatste functie_5',
#  'Huidig/Laatste functie_Beveiliger',
#  'Huidig/Laatste functie_Bezorger',
#  'Huidig/Laatste functie_Chauffeur',
#  'Huidig/Laatste functie_Geen',
#  'Huidig/Laatste functie_Horeca',
#  'Huidig/Laatste functie_Koerier',
#  'Huidig/Laatste functie_Magazijnmedewerker',
#  'Huidig/Laatste functie_Operator',
#  'Huidig/Laatste functie_Schilder',
#  'Huidig/Laatste functie_Student',
#  'Huidig/Laatste functie_Werkloos',
#  'Huidig/Laatste functie_other',
#  'Hoe lang in dienst/werkloos_0',
#  'Hoe lang in dienst/werkloos_1',
#  'Hoe lang in dienst/werkloos_1 jaar',
#  'Hoe lang in dienst/werkloos_1 maand',
#  'Hoe lang in dienst/werkloos_1 week',
#  'Hoe lang in dienst/werkloos_1,5 jaar',
#  'Hoe lang in dienst/werkloos_1jaar',
#  'Hoe lang in dienst/werkloos_2',
#  'Hoe lang in dienst/werkloos_2 jaar',
#  'Hoe lang in dienst/werkloos_2 maanden',
#  'Hoe lang in dienst/werkloos_2,5 jaar',
#  'Hoe lang in dienst/werkloos_3',
#  'Hoe lang in dienst/werkloos_3 jaar',
#  'Hoe lang in dienst/werkloos_3 maanden',
#  'Hoe lang in dienst/werkloos_4',
#  'Hoe lang in dienst/werkloos_4 jaar',
#  'Hoe lang in dienst/werkloos_4 maanden',
#  'Hoe lang in dienst/werkloos_5',
#  'Hoe lang in dienst/werkloos_5 jaar',
#  'Hoe lang in dienst/werkloos_5 maanden',
#  'Hoe lang in dienst/werkloos_6 jaar',
#  'Hoe lang in dienst/werkloos_6 maanden',
#  'Hoe lang in dienst/werkloos_7 jaar',
#  'Hoe lang in dienst/werkloos_7 maanden',
#  'Hoe lang in dienst/werkloos_8 jaar',
#  'Hoe lang in dienst/werkloos_8 maanden',
#  'Hoe lang in dienst/werkloos_9 maanden',
#  'Hoe lang in dienst/werkloos_Nee, ik heb weinig tot nooit klachten',
#  'Hoe lang in dienst/werkloos_Nee, totaal niet. Ik ben fysiek werk en/of een fysieke sport gewend.',
#  'Hoe lang in dienst/werkloos_Niet',
#  'Hoe lang in dienst/werkloos_Nvt',
#  'Hoe lang in dienst/werkloos_other',
#  'Meest trotste project_-',
#  'Meest trotste project_.',
#  'Meest trotste project_Geen',
#  'Meest trotste project_Geen ervaring',
#  'Meest trotste project_Ik heb het niet naar mijn zin bij mijn huidige werk',
#  'Meest trotste project_Ik hoop beter te kunnen doorgroeien binnen de techniek',
#  'Meest trotste project_Nvt',
#  'Meest trotste project_Vriend, familie of kennis die de techniek bij mij vind passen',
#  'Meest trotste project_Vriend, familie of kennis die zelf in de techniek werkt. Dat lijkt mij ook wel wat!',
#  'Meest trotste project_geen',
#  'Meest trotste project_other',
#  'Strevon startsalaris_Dit is een uitdaging',
#  'Strevon startsalaris_Dit is haalbaar',
#  'Strevon startsalaris_Dit is niet haalbaar',
#  'Strevon werktijden_Dit is een uitdaging',
#  'Strevon werktijden_Dit is haalbaar',
#  'Strevon werktijden_Dit is niet haalbaar',
#  'utm_campaign_location_amsterdam',
#  'utm_campaign_location_denhaag',
#  'utm_campaign_location_gouda',
#  'utm_campaign_location_other',
#  'utm_campaign_location_rotterdam',
#  'utm_campaign_location_utrecht',
#  'utm_campaign_no_loc_algemeen',
#  'utm_campaign_no_loc_awareness',
#  'utm_campaign_no_loc_branding',
#  'utm_campaign_no_loc_chat-popup',
#  'utm_campaign_no_loc_consideration',
#  'utm_campaign_no_loc_consideration_elektromonteur',
#  'utm_campaign_no_loc_elektromonteur',
#  'utm_campaign_no_loc_elektrotechniek',
#  'utm_campaign_no_loc_installatiemonteur',
#  'utm_campaign_no_loc_installatiemonteur-exp',
#  'utm_campaign_no_loc_installatiemonteur_exp',
#  'utm_campaign_no_loc_installatietechniek',
#  'utm_campaign_no_loc_other',
#  'utm_campaign_no_loc_retargeting',
#  'utm_campaign_no_loc_undefined',
#  'utm_campaign_no_loc_zonnepanelen_monteur',
#  'utm_adgroup_location_amsterdam',
#  'utm_adgroup_location_denhaag',
#  'utm_adgroup_location_gouda',
#  'utm_adgroup_location_other',
#  'utm_adgroup_location_rotterdam',
#  'utm_adgroup_location_utrecht',
#  'utm_adgroup_no_loc_DSA_LP_Optin',
#  'utm_adgroup_no_loc_DSA_LP_Optin_Elektro',
#  'utm_adgroup_no_loc_DSA_LP_Optin_Installatie',
#  'utm_adgroup_no_loc_bbl_opleiding',
#  'utm_adgroup_no_loc_bbl_opleiding_algemeen',
#  'utm_adgroup_no_loc_betaalde_opleiding',
#  'utm_adgroup_no_loc_betaalde_opleiding_EXP',
#  'utm_adgroup_no_loc_elektricien_opleiding',
#  'utm_adgroup_no_loc_elektromonteur_bbl',
#  'utm_adgroup_no_loc_elektromonteur_opleiding',
#  'utm_adgroup_no_loc_elektrotechniek_bbl',
#  'utm_adgroup_no_loc_elektrotechniek_cursus',
#  'utm_adgroup_no_loc_elektrotechniek_omscholing',
#  'utm_adgroup_no_loc_elektrotechniek_opleiding',
#  'utm_adgroup_no_loc_installateur__divers',
#  'utm_adgroup_no_loc_installateur_opleiding',
#  'utm_adgroup_no_loc_installatietechniek_bbl',
#  'utm_adgroup_no_loc_installatietechniek_opleiding',
#  'utm_adgroup_no_loc_loodgieter_bbl',
#  'utm_adgroup_no_loc_loodgieter_cursus',
#  'utm_adgroup_no_loc_loodgieter_omscholing',
#  'utm_adgroup_no_loc_loodgieter_opleiding',
#  'utm_adgroup_no_loc_loodgieter_worden',
#  'utm_adgroup_no_loc_omscholingstraject',
#  'utm_adgroup_no_loc_opleiding_elektricien',
#  'utm_adgroup_no_loc_other',
#  'utm_adgroup_no_loc_undefined',
#  'utm_adgroup_no_loc_vacature_elektrotechniek',
#  'utm_adgroup_no_loc_vacature_installatiemonteur',
#  'utm_adgroup_no_loc_werk_leer_traject',
#  'utm_adgroup_no_loc_werkleertraject',
#  'utm_adgroup_no_loc_werkleertraject_EXP',
#  'utm_adgroup_no_loc_zonnepanelen_cursus',
#  'utm_adgroup_no_loc_zonnepanelen_opleiding',
#  'parent_page_',
#  'parent_page_contact',
#  'parent_page_omscholing-elektrotechniek-optin',
#  'parent_page_omscholing-elektrotechniek-sea-4',
#  'parent_page_omscholing-installatiemonteur-optin',
#  'parent_page_omscholing-installatiemonteur-sea-4',
#  'parent_page_omscholing-zonnepanelenmonteur-optin',
#  'parent_page_omscholing-zonnepanelenmonteur-sea-4',
#  'parent_page_omscholing-zonwering-optin',
#  'parent_page_opleidingstrajecten',
#  'parent_page_opleidingstrajecten-bouw-techniek',
#  'parent_page_opleidingstrajecten-techniek-paid',
#  'parent_page_other',
#  'parent_page_over-ons',
#  'parent_page_vacatures',
#  'parent_page_vacatures-bouw-techniek',
#  'leeftijd_cat_18-30 jaar',
#  'leeftijd_cat_31-49 jaar',
#  'leeftijd_cat_50 jaar of ouder',
#  'postcode_getal_1000',
#  'postcode_getal_1064',
#  'postcode_getal_1067',
#  'postcode_getal_1069',
#  'postcode_getal_1102',
#  'postcode_getal_2000',
#  'postcode_getal_2037',
#  'postcode_getal_2500',
#  'postcode_getal_2525',
#  'postcode_getal_2700',
#  'postcode_getal_3071',
#  'postcode_getal_3075',
#  'postcode_getal_3079',
#  'postcode_getal_3085',
#  'postcode_getal_3100',
#  'postcode_getal_3131',
#  'postcode_getal_3300',
#  'postcode_getal_3800',
#  'postcode_getal_6600',
#  'postcode_getal_other',
#  'Postcode_1000',
#  'Postcode_1064',
#  'Postcode_1067',
#  'Postcode_1069',
#  'Postcode_1102',
#  'Postcode_2000',
#  'Postcode_2037',
#  'Postcode_2500',
#  'Postcode_2525',
#  'Postcode_2700',
#  'Postcode_3071',
#  'Postcode_3075',
#  'Postcode_3079',
#  'Postcode_3085',
#  'Postcode_3100',
#  'Postcode_3131',
#  'Postcode_3300',
#  'Postcode_3800',
#  'Postcode_6600',
#  'Postcode_other',
#  'Plaats_Alkmaar',
#  'Plaats_Almere',
#  'Plaats_Alphen aan den Rijn',
#  'Plaats_Amersfoort',
#  'Plaats_Amstelveen',
#  'Plaats_Amsterdam',
#  'Plaats_Capelle aan den IJssel',
#  'Plaats_Culemborg',
#  'Plaats_Delft',
#  'Plaats_Den Haag',
#  'Plaats_Dordrecht',
#  'Plaats_Gouda',
#  'Plaats_Haarlem',
#  'Plaats_Hilversum',
#  'Plaats_Hoofddorp',
#  'Plaats_Hoogvliet Rotterdam',
#  'Plaats_Leiden',
#  'Plaats_Maassluis',
#  'Plaats_Nieuwegein',
#  'Plaats_Purmerend',
#  'Plaats_Ridderkerk',
#  'Plaats_Rijswijk',
#  'Plaats_Rotterdam',
#  'Plaats_Schiedam',
#  'Plaats_Spijkenisse',
#  'Plaats_Utrecht',
#  'Plaats_Vlaardingen',
#  'Plaats_Wijchen',
#  'Plaats_Zaandam',
#  'Plaats_Zeist',
#  'Plaats_Zoetermeer',
#  'Plaats_other',
#  'Gemeente_Alkmaar',
#  'Gemeente_Almere',
#  'Gemeente_Alphen aan den Rijn',
#  'Gemeente_Amersfoort',
#  'Gemeente_Amstelveen',
#  'Gemeente_Amsterdam',
#  'Gemeente_Capelle aan den IJssel',
#  'Gemeente_Culemborg',
#  'Gemeente_Delft',
#  'Gemeente_Dordrecht',
#  'Gemeente_Gouda',
#  'Gemeente_Haarlem',
#  'Gemeente_Haarlemmermeer',
#  'Gemeente_Hilversum',
#  'Gemeente_Hoeksche Waard',
#  'Gemeente_Hoorn',
#  'Gemeente_Lansingerland',
#  'Gemeente_Leiden',
#  'Gemeente_Leidschendam-Voorburg',
#  'Gemeente_Maassluis',
#  'Gemeente_Nieuwegein',
#  'Gemeente_Nissewaard',
#  'Gemeente_Noordwijk',
#  'Gemeente_Purmerend',
#  'Gemeente_Ridderkerk',
#  'Gemeente_Rijswijk',
#  'Gemeente_Rotterdam',
#  'Gemeente_Schiedam',
#  'Gemeente_Utrecht',
#  'Gemeente_Velsen',
#  'Gemeente_Vlaardingen',
#  'Gemeente_Westland',
#  'Gemeente_Wijchen',
#  'Gemeente_Zaanstad',
#  'Gemeente_Zeist',
#  'Gemeente_Zoetermeer',
#  'Gemeente_other',
#  'Gemeente_‘s-Gravenhage',
#  'Provincie_Flevoland',
#  'Provincie_Gelderland',
#  'Provincie_Noord-Holland',
#  'Provincie_Utrecht',
#  'Provincie_Zuid-Holland',
#  'Provincie_other']

# %%
df = df[df['uitkomstTelefonischContact_Intake']==1]

# %%
# fill missings 999
df = df.fillna(999)

# Prepare the data
# Replace 'target' with the name of your target column
X = df.drop(columns='starter')
y = df['starter']

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
class_names = ["dropout", "starter"]

# %% [markdown]
# ## create model

# %%
# Initialize and train the Balanced Random Forest model
brf = BalancedRandomForestClassifier(n_estimators=80, random_state=42)
brf.fit(X_train, y_train)

# Make predictions
y_pred = brf.predict(X_test)

# Evaluate the model
print('Classification Report:')
cr = classification_report(y_test, y_pred)
print(cr)


# Create and plot confusion matrix
cm = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(cm, class_names)
# Out:
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93       178
#            1       0.54      0.78      0.64        27
#
#     accuracy                           0.88       205
#    macro avg       0.75      0.84      0.78       205
# weighted avg       0.91      0.88      0.89       205

# %%
# Initialize the model
brf = BalancedRandomForestClassifier(n_estimators=100)

# Apply RFE
rfe = RFE(estimator=brf, n_features_to_select=10)  # Adjust n_features_to_select as needed
rfe.fit(X_train, y_train)

# Transform the dataset with selected features
X_train_rfe = rfe.transform(X_train)
X_test_rfe = rfe.transform(X_test)

# Train the Balanced Random Forest with selected features
brf.fit(X_train_rfe, y_train)

# Evaluate the model
y_pred_rfe = brf.predict(X_test_rfe)
y_proba_rfe = brf.predict_proba(X_test_rfe)[:, 1]

# Print the classification report and plot confusion matrix
print('Classification Report with RFE:')
print(classification_report(y_test, y_pred_rfe))

cm_rfe = confusion_matrix(y_test, y_pred_rfe)
plot_confusion_matrix(cm_rfe, class_names)

# # Calculate and print additional metrics
# roc_auc_rfe = roc_auc_score(y_test, y_proba_rfe)
# print(f'ROC-AUC with RFE: {roc_auc_rfe:.2f}')
# Out:
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# ...
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:577: FutureWarning: The default of `sampling_strategy` will change from `'auto'` to `'all'` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `'all'` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:589: FutureWarning: The default of `replacement` will change from `False` to `True` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `True` to silence this warning and adopt the future behaviour.
#   warn(
# c:\Users\peter\anaconda3\lib\site-packages\imblearn\ensemble\_forest.py:601: FutureWarning: The default of `bootstrap` will change from `True` to `False` in version 0.13. This change will follow the implementation proposed in the original paper. Set to `False` to silence this warning and adopt the future behaviour.
#   warn(
# Classification Report with RFE:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95       178
#            1       0.64      0.78      0.70        27
#
#     accuracy                           0.91       205
#    macro avg       0.80      0.86      0.82       205
# weighted avg       0.92      0.91      0.92       205

# %%
print(f"number of candidates: {len(df)}")
print(f"number of columns: {len(df.columns)}")
# Out:
# number of candidates: 1023
# number of columns: 434

# %%
# Print the classification report and plot confusion matrix
print('Classification Report with RFE:')
print(classification_report(y_test, y_pred_rfe))

class_names = ["geen starter", "starter"]

cm_rfe = confusion_matrix(y_test, y_pred_rfe)
plot_confusion_matrix(cm_rfe, class_names)

# # Calculate and print additional metrics
# roc_auc_rfe = roc_auc_score(y_test, y_proba_rfe)
# print(f'ROC-AUC with RFE: {roc_auc_rfe:.2f}')
# Out:
# Classification Report with RFE:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95       178
#            1       0.64      0.78      0.70        27
#
#     accuracy                           0.91       205
#    macro avg       0.80      0.86      0.82       205
# weighted avg       0.92      0.91      0.92       205

# %%
threshold = 0.1
y_pred_custom = (y_proba_rfe >= threshold).astype(int)

# Print the classification report and plot confusion matrix
print('Classification Report with RFE:')
print(classification_report(y_test, y_pred_custom))

cm_rfe = confusion_matrix(y_test, y_pred_custom)
plot_confusion_matrix(cm_rfe, class_names)
# Out:
# Classification Report with RFE:
#               precision    recall  f1-score   support
#
#            0       0.97      0.17      0.29       178
#            1       0.15      0.96      0.26        27
#
#     accuracy                           0.27       205
#    macro avg       0.56      0.57      0.27       205
# weighted avg       0.86      0.27      0.28       205

# %%
selected_features = X_train.columns[rfe.support_].tolist()
selected_features
# Out:
# ['cdate',
#  'recruitercode',
#  'belafspraak',
#  'leeftijd',
#  'geboortedatum',
#  'Verloning marge stopper of W&S overname',
#  'berekening',
#  'jaar_ervaring',
#  'diff_days',
#  'utm_medium_cpc']

# %%
from datetime import datetime
meta_dict = {"model_type":"brf_rfe",
               "date_created":str(datetime.today().date()),
               "selected_features": selected_features,
               "all_columns": df.columns.to_list(),
               "data_selection": "post_TelefonischUitkomst_Intake",
                "dataset":dataset_name}
import json 
with open(r'C:\Users\peter\Projects\HR_Forecasting\models\model_4_meta.json', "w") as file:
    json.dump(meta_dict, file)

import pickle
with open(r'C:\Users\peter\Projects\HR_Forecasting\models\model_4.pkl', 'wb') as file:
    pickle.dump(brf, file)
